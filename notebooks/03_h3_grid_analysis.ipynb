# %% [markdown]
# # 03 — H3 Grid Analysis
#
# Generate and analyse the H3 hexagonal grid over Jakarta.
#
# - Generate H3 res-8 hexes covering Jakarta bbox
# - Visualise grid density and coverage
# - Compare resolution tradeoffs (res 7 vs 8 vs 9)
# - Overlay with POI locations

# %%
import h3
import geopandas as gpd
from pathlib import Path
import yaml

ROOT = Path('..').resolve()
with open(ROOT / 'config' / 'settings.yaml') as f:
    config = yaml.safe_load(f)
