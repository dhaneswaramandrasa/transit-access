# %% [markdown]
# # 04 — Accessibility Scoring
#
# Compute and analyse transit accessibility scores.
#
# - Load isochrone results (POI counts per hex per threshold)
# - Apply category weights and normalise to 0–100
# - Compute percentile ranks
# - Analyse score distribution and spatial patterns
# - Identify highest/lowest scoring areas

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from pathlib import Path
import yaml

ROOT = Path('..').resolve()
with open(ROOT / 'config' / 'settings.yaml') as f:
    config = yaml.safe_load(f)
