# %% [markdown]
# # 01 — Data Exploration
#
# Explore raw datasets: GTFS feeds, OSM network, POI distribution, and census data.
#
# - Load and inspect GTFS stop locations and route geometries
# - Visualise OSM road network coverage over Jakarta
# - Map POI locations by category
# - Preview BPS population data

# %%
import yaml
from pathlib import Path

ROOT = Path('..').resolve()
with open(ROOT / 'config' / 'settings.yaml') as f:
    config = yaml.safe_load(f)

print(f"Active city: {config['project']['active_city']}")
