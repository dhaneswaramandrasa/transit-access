# %% [markdown]
# # 02 — GTFS Validation
#
# Validate GTFS feeds for TransJakarta, KRL Commuterline, and MRT Jakarta.
#
# - Run gtfs-kit validation on each feed
# - Check date coverage and service calendars
# - Inspect route types and stop counts
# - Identify data quality issues

# %%
import gtfs_kit as gk
from pathlib import Path
import yaml

ROOT = Path('..').resolve()
with open(ROOT / 'config' / 'settings.yaml') as f:
    config = yaml.safe_load(f)
